# %%
import requests

# %%
path = "/api/events/read_events"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{path}"

endpoint
# Out:
# 'http://localhost:8002/api/events/read_events'

# %%
response = requests.get(endpoint)
response
# Out:
# <Response [404]>
