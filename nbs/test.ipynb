# %%
import requests
from pprint import pprint

# Step 1 - create
response = requests.post(
    "http://localhost:8002/api/events/",
    json={"page": "home", "description": "test event"}
)
response.json()
# Out:
# {'description': 'test event', 'id': 11, 'page': 'home'}

# %%
# Step 2 - read all
response = requests.get("http://localhost:8002/api/events/")
pprint(response.json())  # should include the event you just created
# Out:
# {'count': 5,
#  'results': [{'description': 'test event', 'id': 1, 'page': 'home'},
#              {'description': 'test event', 'id': 2, 'page': 'home'},
#              {'description': 'test event', 'id': 3, 'page': 'home'},
#              {'description': 'test event', 'id': 4, 'page': 'home'},
#              {'description': 'test event', 'id': 5, 'page': 'home'}]}

# %%
response = requests.get("http://localhost:8002/api/events/4")
pprint(response.json())
# Out:
# {'description': 'test event', 'id': 4, 'page': 'home'}
