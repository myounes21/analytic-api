# %%
import requests
from pprint import pprint

# Step 1 - create
response = requests.post(
    "http://localhost:8002/api/events/",
    json={"page": "home", "description": "inline test"}
)
response.json()
# Out:
# {'description': 'inline test',
#  'updated_at': '2026-03-07T08:06:56.650288Z',
#  'id': 2,
#  'page': 'home',
#  'created_at': '2026-03-07T08:06:56.650274Z'}

# %%
# Step 2 - read all
response = requests.get("http://localhost:8002/api/events/")
pprint(response.json())  # should include the event you just created
# Out:
# {'count': 1,
#  'results': [{'created_at': '2026-03-07T07:51:21.629163Z',
#               'description': 'inline test',
#               'id': 1,
#               'page': 'home',
#               'updated_at': '2026-03-07T07:51:21.629174Z'}]}

# %%
response = requests.get("http://localhost:8002/api/events/1")
pprint(response.json())
# Out:
# {'created_at': '2026-03-07T07:51:21.629163Z',
#  'description': 'inline test',
#  'id': 1,
#  'page': 'home',
#  'updated_at': '2026-03-07T07:51:21.629174Z'}

# %%
response = requests.put(
    "http://localhost:8002/api/events/1",
    json={"description": "updated description"}
)
pprint(response.json())
# Out:
# {'created_at': '2026-03-07T07:51:21.629163Z',
#  'description': 'updated description',
#  'id': 1,
#  'page': 'home',
#  'updated_at': '2026-03-07T07:59:12.351708Z'}

# %%
response = requests.delete(
    "http://localhost:8002/api/events/2"
)
pprint(response.json())
# Out:
# {'ok': True}
